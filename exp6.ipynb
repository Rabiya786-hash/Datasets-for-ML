# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix,ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv('user_data.csv')

# Check column names (adjust if needed)
print(df.columns)

# Feature & Target (adjust column names as needed)
X = df[['Age', 'EstimatedSalary']]
y = df['Purchased']

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Train model
model = LogisticRegression()
model.fit(X_train, y_train)

# Predict
y_pred = model.predict(X_test)

# Evaluation
lp=confusion_matrix(y_test, y_pred)
print(lp)
print(classification_report(y_test, y_pred))

# Visualize confusion matrix
# sns.heatmap(confusion_matrix(y_test, y_pred), annot=True, cmap='Blues')
disp=ConfusionMatrixDisplay(confusion_matrix=lp,display_labels=model.classes_)
disp.plot(cmap='Blues')
# plt.title('Confusion Matrix')
# plt.xlabel('Predicted')
# plt.ylabel('Actual')
plt.show()
# Out:
# Index(['User ID', 'Gender', 'Age', 'EstimatedSalary', 'Purchased'], dtype='object')
# [[42  8]
#  [ 7 23]]
#               precision    recall  f1-score   support
#
#            0       0.86      0.84      0.85        50
#            1       0.74      0.77      0.75        30
#
#     accuracy                           0.81        80
#    macro avg       0.80      0.80      0.80        80
# weighted avg       0.81      0.81      0.81        80

# %%
new_user = [[35, 60000]]  # Age, EstimatedSalary
result = model.predict(new_user)
print("Purchased" if result== 1 else "Not Purchased")
# Out:
# Not Purchased
# C:\Users\gavan\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
import statsmodels
print(statsmodels.__version__)
# Out:
# 0.14.4

# %%
import seaborn as sns
sns.regplot(x='Age', y='Purchased', data=df,logistic=True)
# Out:
# <Axes: xlabel='Age', ylabel='Purchased'>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Create pairplot to visualize relationships between multiple features
sns.pairplot(df[['Age', 'EstimatedSalary', 'Purchased']])
plt.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression


df=pd.read_csv('user_data.csv')

x=df[['EstimatedSalary','Age']]
y=df['Purchased']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)
model=LogisticRegression()
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

accuracy_scor=accuracy_score(y_test,y_pred)
confusion_matric=confusion_matrix(y_test,y_pred)

dis=ConfusionMatrixDisplay(confusion_matrix=confusion_matric,display_labels=model.classes_)
dis.plot(cmap='Reds')
plt.show()

sns.regplot(x='Age',y='Purchased',data=df, logistic=True)
sns.pairplot(df[['Age','EstimatedSalary','Purchased']])
