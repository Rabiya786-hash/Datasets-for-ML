# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report,accuracy_score, confusion_matrix
import matplotlib.pyplot as plt

# Load data
data = pd.read_csv('diabetes.csv')
X = data.drop('diabetes', axis=1)
y = data['diabetes']

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# Train KNN model
model = KNeighborsClassifier(n_neighbors=5)
model.fit(X_train, y_train)

# Predict and evaluate
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))

# Plot confusion matrix
cm = confusion_matrix(y_test, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=model.classes_)
disp.plot(cmap='Blues')
plt.title("KNN Confusion Matrix")
plt.show()
# Out:
# Accuracy: 0.6796536796536796

# %%
# New person's data (in the same order as your dataset)
new_person = [[4,110,92,0,0,37.6,0.191,30]]

# Predict if the new person has diabetes or not
prediction = model.predict(new_person)

# Output the prediction result
if prediction == 1:
    print("This person is predicted to have diabetes.")
else:
    print("This person is predicted to not have diabetes.")
# Out:
# This person is predicted to not have diabetes.
# C:\Users\gavan\AppData\Roaming\Python\Python313\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but KNeighborsClassifier was fitted with feature names
#   warnings.warn(

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot
import seaborn.sns


df=pd.read_csv('Diabetes.csv')

x=data.drop('diabetes',axis=1)
y=data['diabetes']

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.4)

model=KNeighborsClassifier()
model.fit(x_train,y_train)

predict_y=model.predict(x_test)
print('accuracy:',accuracy_score(y_test,predict_y))

disp=ConfusionMatrixDisplay(confusion_matrix=confusion_matrix(y_test,predict_y),display_labels=model.classes_)
disp.plot(cmap='Reds')
plt.show()
# Out:
# accuracy: 0.7564935064935064
